# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh9559/Data_science/blob/main/Phase%201%20Statistical%20Foundations%20for%20Data%20Science/6%20Statistical_Test/Statistical_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Statistical Test**

# %% [markdown]
# A statistical test is a method used to assess evidence for or against a hypothesis about a population parameter based on sample data.
#
# A statistical test is a mathematical method used to determine whether there is enough evidence in a sample of data to support a specific claim (called a hypothesis) about a population.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Key Concepts:
#
# - Hypotheses:
#   1. Null Hypothesis (H₀): A default assumption that there is no effect or no difference.
#
#   2. Alternative Hypothesis (H₁ or Ha): Suggests that there is an effect or a difference.
#
# - Purpose:
# To assess whether observed data significantly deviates from what we'd expect under the null hypothesis.
#
# - Test Statistic:
# A value calculated from the sample data, which is used to determine whether to reject H₀.
#
# - P-value:
# The probability of obtaining a result at least as extreme as the one observed, assuming H₀ is true.
#
# - Significance Level (α):
# A threshold (commonly 0.05). If p-value < α, reject H₀.
#
# Types of Statistical Tests:
#
# 1. Parametric Tests:
# These tests assume data follows a specific distribution (e.g., normal distribution) and utilize population parameters (like means and standard deviations) in their calculations. Examples include t-tests, z-tests, and ANOVA.
#
# 2. Non-parametric Tests:
# These tests do not make assumptions about the data distribution and are used when data is not normally distributed or when dealing with ordinal or ranked data. Examples include the Mann-Whitney U test, the Kruskal-Wallis test, and the Wilcoxon signed-rank test.

# %% [markdown]
# Examples:
#
# - Testing the effectiveness of a new drug:
# A t-test could be used to compare the recovery rates of patients treated with the new drug versus a placebo.
#
# - Determining if there is a relationship between smoking and lung cancer:
# A chi-square test could be used to analyze the association between smoking status and the presence or absence of lung cancer.
#
# - Comparing the average test scores of students in different schools:
# ANOVA could be used to see if there are significant differences in test scores between multiple schools.

# %% [markdown]
# | Test Type               | Used For                                     | Example                                |
# | ----------------------- | -------------------------------------------- | -------------------------------------- |
# | **t-test**              | Comparing means between groups               | Mean test scores of two classes        |
# | **Chi-square test**     | Categorical data and frequency distributions | Examining gender vs. voting preference |
# | **ANOVA**               | Comparing means among 3 or more groups       | Drug effectiveness across 3 treatments |
# | **Z-test**              | Large sample size mean comparison            | Proportions of defective items         |
# | **Correlation test**    | Measuring relationship between variables     | Height vs. weight                      |
# | **Regression analysis** | Predicting one variable based on another     | Sales based on ad budget               |

# %% [markdown]
# ---

# %% [markdown]
# **One-tailed vs Two-tailed Tests are types of hypothesis tests**
#
# ### **Two-tailed Test**
#
# A **two-tailed test** checks **both directions** — whether a sample is significantly **greater than or less than** the population value.
#
# #### Used When:
#
# You're testing **for any significant difference**, regardless of direction.
#
# #### Example:
#
# > **Hypothesis:** Does a new medicine affect blood pressure differently than the old one?
#
# * H₀: µ = 120 (mean blood pressure is 120)
# * H₁: µ ≠ 120 (it could be **higher or lower**)
#
# You’re interested in **any change**, not just an increase or decrease.
#
# ---
#
# ### **One-tailed Test**
#
# A **one-tailed test** checks in **one direction only** — either for a significant **increase** or **decrease**.
#
# #### Used When:
#
# You're testing for an effect in a **specific direction**.
#
# #### Example 1 (Right-tailed):
#
# > **Hypothesis:** Does a new fertilizer **increase** crop yield?
#
# * H₀: µ ≤ 50 kg (no increase)
# * H₁: µ > 50 kg (**increase** only)
#
# #### Example 2 (Left-tailed):
#
# > **Hypothesis:** Does a new policy **reduce** average waiting time?
#
# * H₀: µ ≥ 30 min
# * H₁: µ < 30 min (**decrease** only)
#
# ---
#
# ##  **Comparison Summary:**
#
# | Feature          | One-tailed Test                       | Two-tailed Test                |
# | ---------------- | ------------------------------------- | ------------------------------ |
# | Direction tested | One (left or right)                   | Both (left and right)          |
# | H₁ form          | µ > value or µ < value                | µ ≠ value                      |
# | Sensitivity      | More powerful if direction is correct | More conservative              |
# | Example          | "Is it **more than** 50?"             | "Is it **different from** 50?" |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is Normal Distribution?** [link text](https://colab.research.google.com/github/Rishabh9559/Data_science/blob/main/Phase%201%20Statistical%20Foundations%20for%20Data%20Science/3.%20Probablity_Distribution/Probablity_Distribution.ipynb#scrollTo=XNOd8Od1CP35)
#
# The Normal Distribution (also called the Gaussian distribution) is a bell-shaped and symmetric probability distribution that is widely used in statistics and data analysis.

# %% [markdown]
# | Property                 | Description                                                    |
# | ------------------------ | -------------------------------------------------------------- |
# | **Shape**                | Symmetrical, bell-shaped                                       |
# | **Mean = Median = Mode** | All are equal and located at the center                        |
# | **Spread**               | Defined by **mean (µ)** and **standard deviation (σ)**         |
# | **Tails**                | Extend infinitely in both directions, but never touch the axis |
# | **Total Area**           | Area under the curve is **1** (or 100%)                        |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Orange color dot- value lies then null hypothesis(H₀) accept.
#
# else we reject the null hypothesis, then we accept Alternative Hypothesis (H₁ or Ha)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  **Type I vs Type II Error**
#
#
# | Feature             | **Type I Error (α)**                        | **Type II Error (β)**                     |
# | ------------------- | ------------------------------------------- | ----------------------------------------- |
# | **Definition**      | Rejecting a true null hypothesis            | Failing to reject a false null hypothesis |
# | **You conclude...** | There **is an effect** when there **isn't** | There **is no effect** when there **is**  |
# | **False...**        | False Positive                              | False Negative                            |
# | **Example**         | Declaring a patient **sick** when healthy   | Declaring a patient **healthy** when sick |
# | **Control Level**   | Controlled by **significance level α**      | Controlled by **sample size, power**      |

# %% [markdown]
# ---

# %% [markdown]
# Scenario 1: A factory produces light bulbs that are supposed to last an average of 800 hours. You take a sample of 50 light bulbs and find that the average lifespan is 790 hours. The standard error (SE) for this sample is 7.5 hours.

# %%
from scipy.stats import norm

# %%
population_mean=800
sample_mean=790
standard_error=7.5
alpha=0.05
z_score=(sample_mean - population_mean) / standard_error

# two tailed test
p_value=2 * norm.cdf(z_score)

if p_value > alpha:
  print(f'Fail to reject the null hypothesis: average lifespan of the light bulbs is approximately 800 hours- {p_value:.2f} ')
else:
  print(f"Reject the null hypothesis: average lifespan of the light bulb is not 800 hours - {p_value}")
# Out:
# Fail to reject the null hypothesis: average lifespan of the light bulbs is approximately 800 hours- 0.18
