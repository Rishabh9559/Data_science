# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh9559/Data_science/blob/main/SQL/Delete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DELETE**
#
# Delete used to delete rows, records

# %% [markdown]
# Delete row by id
# ```
# DELETE FROM employe-table WHERE id=5
#
# ```
#
#
# Delete duplicate Email
#
# ```
# DELETE P FROM Person P JOIN Person Q ON P.email=Q.email AND P.id>Q.id
#
# ```
