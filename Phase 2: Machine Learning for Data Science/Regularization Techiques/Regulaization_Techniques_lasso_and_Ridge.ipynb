# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh9559/Data_science/blob/main/Phase%202%3A%20Machine%20Learning%20for%20Data%20Science/Regularization%20Techiques/Regulaization_Techniques_lasso_and_Ridge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Regularization Techniques: Lasso and Ridge Regression
#
# **Regularization** is a technique used in machine learning to prevent **overfitting** by adding a penalty term to the loss function. The goal is to keep the model weights small and avoid relying too much on any one feature.
#
# Two of the most common regularization techniques in linear regression are:
#
# ---
#
# ## 🔹 1. **Ridge Regression (L2 Regularization)**
#
# * **Adds penalty:**
#
#   $$
#   \text{Loss Function} = \text{MSE} + \lambda \sum_{j=1}^{n} w_j^2
#   $$
#
#   where:
#
#   * $\text{MSE}$ = Mean Squared Error
#   * $w_j$ = model coefficients
#   * $\lambda$ = regularization strength (hyperparameter)
#
# * **Effect:** It **shrinks coefficients** towards zero but **does not make them exactly zero**. Useful when many small/medium effects exist.
#
# * **Use case:** Works well when all features are relevant or collinear (e.g., multicollinearity problems).
#
# ---
#
# ## 🔹 2. **Lasso Regression (L1 Regularization)**
#
# * **Adds penalty:**
#
#   $$
#   \text{Loss Function} = \text{MSE} + \lambda \sum_{j=1}^{n} |w_j|
#   $$
#
# * **Effect:** It **shrinks some coefficients to exactly zero**, performing **feature selection**.
#
# * **Use case:** Useful when you suspect only a **few features are important** (sparse solutions).
#
# ---
#
# ## 🔄 Comparison:
#
# | Feature               | Ridge (L2)           | Lasso (L1)                             |      |   |
# | --------------------- | -------------------- | -------------------------------------- | ---- | - |
# | Penalty Term          | $\lambda \sum w_j^2$ | ( \lambda \sum                         | w\_j | ) |
# | Feature Selection     | ❌ No                 | ✅ Yes                                  |      |   |
# | Coefficients become 0 | ❌ No                 | ✅ Yes (some)                           |      |   |
# | Best for              | Many small effects   | Few important features                 |      |   |
# | Stability             | More stable          | Less stable if features are correlated |      |   |
#
# ---
#
# ## 🔂 Elastic Net: Hybrid of Both
#
# * Combines L1 and L2:
#
#   $$
#   \text{Loss} = \text{MSE} + \alpha \left( \lambda_1 \sum |w_j| + \lambda_2 \sum w_j^2 \right)
#   $$
# * Useful when you want both **shrinkage** and **feature selection**.
#
# ---
#
# ##
#
# * **Lasso**: Great for reducing dimensionality by selecting important features.
# * **Ridge**: Great when all features are useful but may be collinear.
# * **Elastic Net**: When you want a balance between Lasso and Ridge.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 📉 1. **What is Underfitting**
#
# * **Definition**:
#   The model is **too simple** to capture the underlying patterns in the data.
#
# * **Symptoms**:
#
#   * High error on **training** data
#   * High error on **testing** data
#   * Poor performance everywhere
#
# * **Causes**:
#
#   * Model is too simple (e.g., linear model on complex data)
#   * Not enough features
#   * Too much regularization
#   * Not enough training time
#
# * **Example**:
#   Predicting house prices using only the number of rooms, ignoring location, size, etc.
#
# ---
#
# ## 📈 2. **What is Overfitting**
#
# * **Definition**:
#   The model is **too complex** and fits the **noise** in the training data instead of generalizing.
#
# * **Symptoms**:
#
#   * Very low error on **training** data
#   * High error on **testing** data
#
# * **Causes**:
#
#   * Too many features or parameters
#   * Too few training examples
#   * Lack of regularization
#   * Training too long
#
# * **Example**:
#   A model that memorizes the training dataset but performs poorly on new, unseen data.
#
# ---
#
# ## 🔄 Comparing Overfitting vs Underfitting
#
# | Feature           | Underfitting        | Overfitting        |
# | ----------------- | ------------------- | ------------------ |
# | Model Complexity  | Too low (simple)    | Too high (complex) |
# | Training Accuracy | Low                 | Very high          |
# | Test Accuracy     | Low                 | Low                |
# | Generalization    | Poor                | Poor               |
# | Cause             | Too little learning | Too much learning  |
#
# ---
#
# ## 📊 Ideal: **Good Fit**
#
# * **Balanced model** that captures the pattern in the data but doesn’t memorize it.
# * **Low training error** and **low validation/test error**
#
# ---
#
# ## 🛠️ How to Fix
#
# * ✅ **Underfitting**:
#
#   * Use more complex model
#   * Add more features
#   * Reduce regularization
#   * Train longer
#
# * ✅ **Overfitting**:
#
#   * Use simpler model
#   * Use regularization (L1/L2)
#   * Use more training data
#   * Apply dropout (for neural networks)
#   * Use early stopping
#
# ---

# %% [markdown]
# ##  What is **Noise** in Machine Learning?
#
# **Noise** refers to **irrelevant or random variations** in data that do **not represent true underlying patterns**.
#
# ---
#
# ### 🔍 Examples of Noise:
#
# * Measurement errors in sensors
# * Typing mistakes in data entry
# * Irrelevant data (e.g., including a user’s IP address in a movie recommendation model)
# * Outliers that don’t follow the general pattern
#
# ---
#
# ### ⚠️ Why Noise is a Problem:
#
# * Makes the model learn **incorrect patterns**
# * Can lead to **overfitting**, especially if the model is too complex
# * Reduces **accuracy** on unseen (test) data
#
# ---
#
# ### 🧹 How to Reduce Noise:
#
# * Data cleaning (removing outliers, correcting errors)
# * Feature selection
# * Smoothing techniques or filters
# * Regularization techniques (like Lasso, Ridge)
#
# ---
#
# ## 🧠 What is **Generalizing**?
#
# In machine learning, **generalization** refers to a model's ability to accurately predict outcomes on new, unseen data after being trained on a specific dataset. A model that generalizes well can apply the patterns it learned from the training data to make reliable predictions on data it has not encountered before
#
# ---
#
# ### 🔍 Why It Matters:
#
# * A model that generalizes well will work on **real-world data**, not just memorized training samples.
# * Generalization is the **goal** of most ML models — we want them to **learn patterns**, not just remember the training set.
#
# ---
#
# ### 🎯 Good Generalization:
#
# * Low error on **training** data ✅
# * Low error on **test/validation** data ✅
# * Model learned the **true relationship** between input and output ✅
#
# ---
#
# ### 🔁 Bad Generalization:
#
# * Happens in **overfitting** — the model memorizes training noise instead of learning real patterns.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Regularization Technique
# - to avoid the issue of Overfitting by modifying the cost function of a given model.
#
#
# 1. Lassa Regression (L1 Regularization)
#
#   $$
#   \text{Loss Function} = \text{MSE} + \lambda \sum_{j=1}^{n} |w_j|
#   $$
#
# ![image.png](data:image/png;base64,...)
#
#
#
# 2.  Redge Regression (L2 Regularization)
#
# 3.  Elastic Net Regression ( L1 and L2)
#   it is combintion of both of L1 and L2.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
print(housing.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(housing.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
dataset = pd.DataFrame(housing.data, columns=housing.feature_names)
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
dataset['Price'] = housing.target
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
# Train Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=44)

# %%
X_train
# Out:
#        MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5567   2.6618      19.0   4.666667   1.142132      2047.0  3.463621     33.88
# 3116   3.9261      12.0   5.657303   1.044944      1027.0  2.884831     35.63
# 4750   2.5320      39.0   3.734257   1.022670      2638.0  3.322418     34.04
# 13963  3.9688      15.0  16.550562   3.078652       622.0  2.329588     34.24
# 2262   1.9575      24.0   4.528424   1.058140      2098.0  2.710594     36.79
# ...       ...       ...        ...        ...         ...       ...       ...
# 18528  3.2437      44.0   4.996139   1.038610       645.0  2.490347     36.96
# 20355  1.9811      16.0   6.104730   1.168919       587.0  1.983108     34.19
# 16955  6.0000      40.0   5.990196   1.006536       751.0  2.454248     37.53
# 3491   5.1408      33.0   5.359862   0.913495       881.0  3.048443     34.27
# 14100  1.5517      31.0   3.110831   0.974811       816.0  2.055416     32.76
#
#        Longitude
# ...

# %%
y_train
# Out:
# 5567     1.797
# 3116     1.013
# 4750     1.727
# 13963    1.828
# 2262     0.670
#          ...
# 18528    2.239
# 20355    1.625
# 16955    3.842
# 3491     2.229
# 14100    1.225
# Name: Price, Length: 16512, dtype: float64

# %% [markdown]
# Data Standardization
#
# Task 2: Why we are not doing fit_transform in the test set and let's say if we do fit_transform in the test set what will be the impact on the model's result?
#
# Data Leakage (major problem in the industry work)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-6.39313890e-01, -7.70123468e-01, -3.18448077e-01, ...,
#          3.12799921e-02, -8.18307745e-01,  6.42275354e-01],
#        [ 2.55369484e-02, -1.32842869e+00,  9.00311043e-02, ...,
#         -1.86339026e-02,  2.97361003e-05,  9.01327246e-01],
#        [-7.07571138e-01,  8.25034301e-01, -7.02917949e-01, ...,
#          1.91028816e-02, -7.43488318e-01,  6.22348286e-01],
#        ...,
#        [ 1.11612791e+00,  9.04792190e-01,  2.27296098e-01, ...,
#         -5.57667090e-02,  8.88510430e-01, -1.36039504e+00],
#        [ 6.64304894e-01,  3.46486970e-01, -3.26160516e-02, ...,
#         -4.52430976e-03, -6.35935392e-01,  5.47621779e-01],
#        [-1.22307638e+00,  1.86971194e-01, -9.59981326e-01, ...,
#         -9.01614158e-02, -1.34204373e+00,  1.23510564e+00]])

# %%
X_test
# Out:
# array([[ 2.86260705e-01,  4.26244859e-01,  1.69578464e-01, ...,
#          3.46072137e-02, -5.75144608e-01,  2.93551655e-01],
#        [ 1.22103793e+00,  5.85760636e-01,  3.59063490e-01, ...,
#         -4.55110319e-02,  8.18367217e-01, -1.25577793e+00],
#        [ 3.30009692e+00, -2.12600757e+00,  1.84207456e+00, ...,
#          5.84330242e-02, -9.30536885e-01,  9.71071986e-01],
#        ...,
#        [ 1.36307401e+00, -1.48794446e+00,  7.33317830e-01, ...,
#          3.61134621e-02, -1.24384324e+00,  1.21517858e+00],
#        [ 3.99637151e-01, -5.23024719e-02,  3.47527685e-01, ...,
#          2.32720415e-02,  1.10829250e+00, -1.22090556e+00],
#        [-9.16129109e-01,  1.22382374e+00, -3.40511886e-01, ...,
#         -3.02836919e-03, -7.62193175e-01,  6.37293587e-01]])

# %% [markdown]
# Model Training
#
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [ 0.83215514  0.11519221 -0.2633912   0.31621969 -0.00115802 -0.03990048
#  -0.90741623 -0.87609073]

# %%
print(model.intercept_)
# Out:
# 2.067763302446704

# %% [markdown]
# Lasso Regression (L1 Regularization)

# %%
from sklearn.linear_model import Lasso
model_lasso = Lasso()

# %% [markdown]
# Ridge Regression (L2 Regularization)

# %%
from sklearn.linear_model import Ridge
model_ridge = Ridge()

# %% [markdown]
# Elastic Net Regression (Combination of L1 and L2)

# %%
from sklearn.linear_model import ElasticNet
model_elastic_net = ElasticNet()

# %%
model_lasso.fit(X_train, y_train)
model_ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
model_elastic_net.fit(X_train, y_train)
# Out:
# ElasticNet()

# %% [markdown]
# Model Prediction

# %%
y_cap = model.predict(X_test)
print(y_cap)
# Out:
# [2.55823281 3.35684836 4.09751962 ... 2.80867915 2.38870762 1.61280809]

# %%
y_cap_lasso=model_lasso.predict(X_test)
print(y_cap_lasso)
# Out:
# [2.0677633 2.0677633 2.0677633 ... 2.0677633 2.0677633 2.0677633]

# %%
y_cap_ridge = model_ridge.predict(X_test)
print(y_cap_ridge)
# Out:
# [2.55805966 3.35658646 4.0975895  ... 2.80868816 2.38863631 1.61282596]

# %%
y_cap_elasticNet = model_elastic_net.predict(X_test)
print(y_cap_elasticNet)
# Out:
# [2.12337531 2.30497493 2.70887472 ... 2.33256835 2.145401   1.88978646]

# %% [markdown]
# Model Evaluation

# %%
residuals = y_test - y_cap
residuals
# Out:
# 20127    0.822767
# 18256    0.715152
# 10376    0.743480
# 4109     1.707415
# 8169    -0.172330
#            ...
# 2312    -0.014145
# 18574   -0.691329
# 14552   -0.313679
# 1430    -0.606708
# 4977    -0.554808
# Name: Price, Length: 4128, dtype: float64

# %%
# Normality -> Distribution plot of the above residuals == it should be normally distributed
sns.distplot(residuals, kde=True)
# Out:
# /tmp/ipython-input-31-2593592280.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, kde=True)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#  lasso
residuals = y_test - y_cap_lasso
residuals
# Out:
# 20127    1.313237
# 18256    2.004237
# 10376    2.773237
# 4109     2.932247
# 8169     0.424237
#            ...
# 2312    -0.659763
# 18574   -0.553763
# 14552    0.427237
# 1430    -0.285763
# 4977    -1.009763
# Name: Price, Length: 4128, dtype: float64

# %%
# Normality -> Distribution plot of the above residuals == it should be normally distributed
sns.distplot(residuals, kde=True)
# Out:
# /tmp/ipython-input-33-2593592280.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, kde=True)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#  Ridge

residuals = y_test - y_cap_ridge
residuals
# Out:
# 20127    0.822940
# 18256    0.715414
# 10376    0.743411
# 4109     1.707441
# 8169    -0.172325
#            ...
# 2312    -0.014418
# 18574   -0.690954
# 14552   -0.313688
# 1430    -0.606636
# 4977    -0.554826
# Name: Price, Length: 4128, dtype: float64

# %%
sns.distplot(residuals, kde=True)
# Out:
# /tmp/ipython-input-36-2998397011.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals, kde=True)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#  elasticNet
residuals=y_test-y_cap_elasticNet
residuals
# Out:
# 20127    1.257625
# 18256    1.767025
# 10376    2.132125
# 4109     2.658891
# 8169     0.304999
#            ...
# 2312    -0.662385
# 18574   -0.419153
# 14552    0.162432
# 1430    -0.363401
# 4977    -0.831786
# Name: Price, Length: 4128, dtype: float64

# %%
sns.distplot(residuals,kde=True)
# Out:
# /tmp/ipython-input-38-3762910054.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals,kde=True)
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# MOdel Evalution

# %%
#
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(mean_squared_error(y_test, y_cap))
print(mean_absolute_error(y_test, y_cap))
print(np.sqrt(mean_squared_error(y_test, y_cap)))
# Out:
# 0.5347838950335048
# 0.5278504031670417
# 0.7312892006815804

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(mean_squared_error(y_test, y_cap_lasso))
print(mean_absolute_error(y_test, y_cap_lasso))
print(np.sqrt(mean_squared_error(y_test, y_cap_lasso)))
# Out:
# 1.3657988826860425
# 0.9288342032391992
# 1.1686739847733596

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(mean_squared_error(y_test, y_cap_ridge))
print(mean_absolute_error(y_test, y_cap_ridge))
print(np.sqrt(mean_squared_error(y_test, y_cap_ridge)))
# Out:
# 0.5347633787931912
# 0.527850234803036
# 0.7312751731005172

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(mean_squared_error(y_test, y_cap_elasticNet))
print(mean_absolute_error(y_test, y_cap_elasticNet))
print(np.sqrt(mean_squared_error(y_test, y_cap_elasticNet)))
# Out:
# 1.0921710836648864
# 0.8276574876887405
# 1.0450698941529635
