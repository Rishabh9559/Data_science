# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh9559/Data_science/blob/main/Phase%202%3A%20Machine%20Learning%20for%20Data%20Science/Naive_Bayes/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Naive Bayes is a **probabilistic machine learning algorithm** based on **Bayes’ Theorem**, commonly used for classification tasks.
#
# ###  Key Idea:
#
# It assumes that all features are **independent** of each other given the class label — which is usually not true in real-world data, but the assumption ("naive") works surprisingly well in practice.
#
#
# ###  Bayes’ Theorem:
#
# $$
# P(C \mid X) = \frac{P(X \mid C) \cdot P(C)}{P(X)}
# $$
#
# Where:
#
# * $P(C \mid X)$: Posterior probability of class $C$ given input features $X$.
# * $P(X \mid C)$: Likelihood (probability of input features given class $C$).
# * $P(C)$: Prior probability of class $C$.
# * $P(X)$: Evidence (probability of the input features).
#
# Naive Bayes simplifies this by assuming features are conditionally independent:
#
# $$
# P(X \mid C) = P(x_1 \mid C) \cdot P(x_2 \mid C) \cdot \dots \cdot P(x_n \mid C)
# $$
#
#
#
# ###  Types of Naive Bayes:
#
# 1. **Gaussian Naive Bayes** – assumes features follow a normal (Gaussian) distribution.
# 2. **Multinomial Naive Bayes** – good for text classification (e.g., spam detection).
# 3. **Bernoulli Naive Bayes** – works with binary features (e.g., word present or not).
#
#
#
# ###  Advantages:
#
# * Very fast to train and predict.
# * Works well with high-dimensional data (like text classification).
# * Simple and easy to implement.
#
# ###  Limitations:
#
# * Assumes independence among features (rarely true).
# * Struggles when features are correlated.
# * Can give poor probability estimates, though classification is often good.
#
#
#  **Example Use Case**:
#
# * **Spam Detection**:
#
#   * Features = words in an email.
#   * Class = Spam or Not Spam.
#   * Naive Bayes calculates probabilities of spam vs. non-spam and picks the higher one.

# %% [markdown]
# Question
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# import libery
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# %%
X, y = load_iris(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
# array([[5.5, 2.4, 3.7, 1. ],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.6, 3. , 4.4, 1.4],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.7, 2.9, 4.2, 1.3],
#        [7.6, 3. , 6.6, 2.1],
#        [5.6, 3. , 4.5, 1.5],
#        [5.1, 3.5, 1.4, 0.2],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.8, 2.7, 4.1, 1. ],
#        [5.2, 3.4, 1.4, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [5.1, 3.8, 1.9, 0.4],
#        [5. , 2. , 3.5, 1. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.7, 3. , 4.2, 1.2],
#        [7.7, 3.8, 6.7, 2.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.7, 2.5, 5. , 2. ],
#        [5.5, 4.2, 1.4, 0.2],
#        [6. , 3. , 4.8, 1.8],
#        [5.8, 2.7, 5.1, 1.9],
#        [6. , 2.2, 4. , 1. ],
#        [5.4, 3. , 4.5, 1.5],
#        [6.2, 3.4, 5.4, 2.3],
# ...

# %%
y_train
# Out:
# array([1, 2, 2, 1, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0, 1,
#        2, 0, 1, 2, 0, 2, 2, 1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 1, 0, 2, 0, 0,
#        1, 1, 2, 1, 2, 2, 1, 0, 0, 2, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 1, 1,
#        2, 1, 2, 0, 2, 1, 2, 1, 1, 1, 0, 1, 1, 0, 1, 2, 2, 0, 1, 2, 2, 0,
#        2, 0, 1, 2, 2, 1, 2, 1, 1, 2, 2, 0, 1, 2, 0, 1, 2])

# %%
# count value by using pandas
print(pd.Series(y_test).value_counts())
# Out:
# 0    19
# 1    13
# 2    13
# Name: count, dtype: int64

# %%
from collections import Counter
print(Counter(y_train))
# Out:
# Counter({np.int64(1): 37, np.int64(2): 37, np.int64(0): 31})

# %% [markdown]
# ## Application :
# 1. Span detetction
# 2. Sentiment Analysis
# 3. Medical Diagnosis

# %%
# model
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 97.77777777777777
