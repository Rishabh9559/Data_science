# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh9559/Data_science/blob/main/python/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# install - pip install pandas
# <br> **Pandas** is a Python library primarily used for data manipulation and analysis. <br>It offers data structures like DataFrames and Series that facilitate working with structured data, such as tables and time series. <br>It was created by Wes McKinney in 2008

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# pip install pandas
import pandas as pd

# %%
# read file
data=pd.read_csv('/content/dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# why we used pd to load file , not used system or file handler to load the file .<br> to used pands frame we need to load file using pd.read fucnction

# %% [markdown]
# Display the first data set

# %%
# Top five data print
# index start form 0
data.head() # default value is five.
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#  define to get custom
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %% [markdown]
# Display the last fews data

# %%
#  last five data load
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
#  custom based load
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
# error handling with pands
try:
  data=pd.read_csv('/content/dataset.csv')
except Exception as e:
  print("exception occurs: ",e)
# Out:
# exception occurs:  [Errno 2] No such file or directory: '/content/dataset.csv'

# %%
type(data)
# Out:
# list

# %% [markdown]
# **What is Data Structure** : a ways to structure the data in a efficient manner.<br> Two types of data structure: <br>
# - Linear : Array, LinkedList, Stack and quick.<br>
# - Non-Liner : Hashing, Tree and Graph <br>
#
#
# <br>
# Which types of DataStructure used in Pands
# <br>
# A: DataFrame <br>
# - Row and cloumn <br>
# - Structure formate <br>
#
# B: Series one dimenional array. <br>
#
# **Series**: a one-dimensional labeled array holding data of any type
# <br>
#
#
# **DataFrame**: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.

# %%
data['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %% [markdown]
# [link text](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html#pandas.Series)
# Create a serise form scalar value with custome index

# %%
series_scalar=pd.Series(5,index=['a','b','c','d','e'])
print(series_scalar)
print(series_scalar['c']) # index number
# Out:
# a    5
# b    5
# c    5
# d    5
# e    5
# dtype: int64
# 5

# %%
d={'rtgfe': 67, 'tyuie': 23, 'qwert': 98, 'asdfg': 45, 'zxcvb': 12, 'hjklm': 76, 'poiuy': 34, 'lkjhg': 89}

serise_pd=pd.Series(d)
print(serise_pd[1:5])
# Out:
# tyuie    23
# qwert    98
# asdfg    45
# zxcvb    12
# dtype: int64

# %% [markdown]
# Attributes in serise data structure

# %%
data = ['New Delhi', 'Washington', 'London', 'Paris']
index = ['India', 'USA', 'UK', 'France']
series_capital=pd.Series(data,index) # data , index
print(series_capital)
# Out:
# India      New Delhi
# USA       Washington
# UK            London
# France         Paris
# dtype: object

# %%
#  only index display
print("index only")
print(series_capital.index)
# Out:
# index only
# Index(['India', 'USA', 'UK', 'France'], dtype='object')

# %%
#  only value
print("value only")
print(series_capital.values)
# Out:
# value only
# ['New Delhi' 'Washington' 'London' 'Paris']

# %% [markdown]
# different between type() and dtype()
# <br>
# - dtype: is data type of each element in that data structure <br>
# - type: check the data type of data structure.

# %%
print("Data type of the series_capital_country")
print(series_capital.dtype)
# Out:
# Data type of the series_capital_country
# object

# %%
print("Size of the series_capital_country")
print(series_capital.size)
# Out:
# Size of the series_capital_country
# 4

# %%
print("Shape of the series_capital_country")
print(series_capital.shape)
# Out:
# Shape of the series_capital_country
# (4,)

# %%
print("is serise contains uique elements")
print(series_capital.is_unique)
# Out:
# is serise contains uique elements
# True

# %%
#  Empty serise
empty_series=pd.Series()
print(empty_series)
# Out:
# Series([], dtype: object)

# %% [markdown]
# NaN : Not a Number or missing value or undefine numberical data<br>
#
# Null : missing value and not refer any type

# %%
# series_capital.head()
series_capital.tail()
# Out:
# India      New Delhi
# USA       Washington
# UK            London
# France         Paris
# dtype: object

# %%
marks=[99,98,97,45,88]
student=['Rishabh','Rahul','Vaishnavi','Radheeka','Vani']


series_student=pd.Series(marks,index=student)

print(series_student)
# Out:
# Rishabh      99
# Rahul        98
# Vaishnavi    97
# Radheeka     45
# Vani         88
# dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Data given in form of: <br>
# - Business understanding
# <br>
# - Data collection <br>
# - EDA (Exploratory Data Analysis)

# %% [markdown]
# - median
# <br>
# - mean <br>
# - min <br>
# - max

# %%
series_student.describe() # display all statistics data
# Out:
# count     5.000000
# mean     85.400000
# std      23.006521
# min      45.000000
# 25%      88.000000
# 50%      97.000000
# 75%      98.000000
# max      99.000000
# dtype: float64

# %% [markdown]
# value_count()

# %%
series_student.value_counts()
# Out:
# 99    1
# 98    1
# 97    1
# 45    1
# 88    1
# Name: count, dtype: int64

# %%
#  sort_value()
series_student.sort_values()
# Out:
# Radheeka     45
# Vani         88
# Vaishnavi    97
# Rahul        98
# Rishabh      99
# dtype: int64

# %%
# drop()
series_student = series_student.drop('Rahul')
series_student
# Out:
# Rishabh      99
# Vaishnavi    97
# Radheeka     45
# Vani         88
# Karan        91
# dtype: int64

# %% [markdown]
# isNull()

# %%
print(series_student.isnull())
# Out:
# Rishabh      False
# Rahul        False
# Vaishnavi    False
# Radheeka     False
# Vani         False
# dtype: bool

# %% [markdown]
# Mathematical Operations on Series <br>
# 1. Addition of two Series
#
# 2. Subtraction of two Series
#
# 3. Multiplication of two Series
#
# 4. Division of two Series

# %%
#  add element
series_student['Karan'] = 91
series_student
# Out:
# Rishabh      99
# Vaishnavi    97
# Radheeka     45
# Vani         88
# Karan        91
# dtype: int64

# %% [markdown]
# next parts-------

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/dataset.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# **Add new column**

# %%
data['country']='India'

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked country
# 0   330911   7.8292   NaN        Q   India
# 1   363272   7.0000   NaN        S   India
# 2   240276   9.6875   NaN        Q   India
# 3   315154   8.6625   NaN        S   India
# 4  3101298  12.2875   NaN        S   India

# %% [markdown]
# **Add column at perticular position**

# %%
data.insert(loc=2,column='sex',value=6)

# %%
data.head()
# Out:
#    PassengerId  Survived  sex  Pclass  \
# 0          892         0    6       3
# 1          893         1    6       3
# 2          894         0    6       2
# 3          895         0    6       3
# 4          896         1    6       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked country
# 0   330911   7.8292   NaN        Q   India
# 1   363272   7.0000   NaN        S   India
# 2   240276   9.6875   NaN        Q   India
# 3   315154   8.6625   NaN        S   India
# 4  3101298  12.2875   NaN        S   India

# %% [markdown]
# **Delete the column by name**

# %%
data.drop(columns='sex')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data=pd.read_excel("/content/customers.xlsx")

# %%
data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0

# %% [markdown]
# **Create a new column 'FullName' which is composed of first and last name.**

# %%
val=data['first_name']+data['last_name']
data.insert(loc=1,column='Full Name',value=val)  # insert at perticular postion and combine two differsent column data

# %%
data.head()
# Out:
#        id          Full Name first_name    last_name  \
# 0       1    RomainSouthcott     Romain    Southcott
# 1       2    CosimoMolyneaux     Cosimo    Molyneaux
# 2       3       BambiWestrip      Bambi      Westrip
# 3       4   RoarkePankettman     Roarke   Pankettman
# 4       5    MikaelaAlthorpe    Mikaela     Althorpe
# ..    ...                ...        ...          ...
# 995   996       MerriliAlman    Merrili        Alman
# 996   997      WinonahHeckle    Winonah       Heckle
# 997   998          TobitBirt      Tobit         Birt
# 998   999  IssiahStandbrooke     Issiah  Standbrooke
# 999  1000       ElmoreMalpas     Elmore       Malpas
#
#                               email  gender  street_num street_name  \
# 0         rsouthcott0@clickbank.net    Male         1.0   Trailsway
# 1             cmolyneaux1@wiley.com    Male         NaN         NaN
# 2            bwestrip2@symantec.com  Female      4057.0    Arkansas
# ...
