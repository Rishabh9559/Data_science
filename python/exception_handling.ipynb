# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh9559/Data_science/blob/main/python/exception_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exception Handling** : Exception handling is a mechanism in programming that allows a program to respond to exceptional or anomalous situations during runtime, preventing it from crashing or misbehaving

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Syntax error
print('ej) # this is systex error , you just miss or mistake any code syntax

# %%
# Logical error : In terminal or code execution there was no error
def area(l,b):
  return l+b # this logic for rectanger perimeter

print(area(4,9))
# Out:
# 13

# %%
# Runtime error : code is correct but at terminal error
a=0
b=10
ans= b//a  #ZeroDivisionError: integer division or modulo by zero
print(ans)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-3284d1d6ed17> in <cell line: 0>()
#       2 a=0
#       3 b=10
# ----> 4 ans= b//a
#       5 print(ans)
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Erro Handling** : Try , Except , else , try

# %%
# zero division error
try:
  a=0
  b=10
  res=b//a
  print(res)
except :
  print("zero division error")
# Out:
# zero division error

# %%
# finally : always run if there error or not
## typically used fr cleanUp action, closing files or released resource

try:
  a=5  # -- a=0
  b=20
  print(b//a)
except:
  print("zero divide error")
finally:## typically used fr cleanUp action, closing files or released resource
  print("code executed")
# Out:
# 4
# code executed

# %%
# else: if try statement then only else executed
try:
  a=int(input('Enter the number :'))
  res=20//a
except ZeroDivisionError:
  print('zero divide error')

except ValueError:
  print('value error')

else:
  print("result :",res)

finally:
  print("code executed all")
# Out:
# Enter the number :0
# zero divide error
# code executed all
